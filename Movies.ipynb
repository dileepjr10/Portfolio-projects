# %%
import pandas as pd
import numpy as np
import seaborn as sns
import dateutil.parser as parser

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv(r'C:\Users\dilee\OneDrive\Desktop\movies.csv')

# %%
#captilizing all the column names

df.columns = df.columns.str.capitalize()
df
# Out:
#                                                 Name Rating      Genre  Year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#checking for any null values (where any field in any column is null), 
#replace any with all to see the rows which are completely null
df[df.isnull().any(axis=1)]
# Out:
#                  Name Rating   Genre  Year                           Released  \
# 16               Fame      R   Drama  1980       May 16, 1980 (United States)
# 19         Stir Crazy      R  Comedy  1980  December 12, 1980 (United States)
# 24       Urban Cowboy     PG   Drama  1980       June 6, 1980 (United States)
# 25     Altered States      R  Horror  1980  December 25, 1980 (United States)
# 26    Little Darlings      R  Comedy  1980     March 21, 1980 (United States)
# ...               ...    ...     ...   ...                                ...
# 7663     More to Life    NaN   Drama  2020   October 23, 2020 (United States)
# 7664      Dream Round    NaN  Comedy  2020   February 7, 2020 (United States)
# 7665    Saving Mbango    NaN   Drama  2020          April 27, 2020 (Cameroon)
# 7666     It's Just Us    NaN   Drama  2020    October 1, 2020 (United States)
# 7667        Tee em el    NaN  Horror  2020    August 19, 2020 (United States)
#
# ...

# %%
#checking for the number of nulls in each column
for col in df.columns:
    pct_missing = sum(df[col].isnull())
    print('{} - {}'.format(col, round(pct_missing)))
# Out:
# Name - 0
# Rating - 77
# Genre - 0
# Year - 0
# Released - 2
# Score - 3
# Votes - 3
# Director - 0
# Writer - 3
# Star - 1
# Country - 3
# Budget - 2171
# Gross - 189
# Company - 17
# Runtime - 4

# %%
#Filtering out the null records
df = df[df['Budget'].notnull() & df['Gross'].notnull()]
df
#sum(nullva['Budget'].isnull())
# Out:
#                                                 Name     Rating      Genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       Year                           Released  Score      Votes  \
# ...

# %%
#checking for any duplicated rows
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Rating, Genre, Year, Released, Score, Votes, Director, Writer, Star, Country, Budget, Gross, Company, Runtime]
# Index: []

# %%
#checking duplicates wrt specific columns
df[df.duplicated(subset = ['Name','Year'])]
# Out:
# Empty DataFrame
# Columns: [Name, Rating, Genre, Year, Released, Score, Votes, Director, Writer, Star, Country, Budget, Gross, Company, Runtime]
# Index: []

# %%
#dropping the duplicates
df = df.drop_duplicates(subset = ['Name','Year'])
df
# Out:
#                                                 Name     Rating      Genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       Year                           Released  Score      Votes  \
# ...

# %%
#df[df['genre'].duplicated()]['genre']
df['Genre'].unique()
# Out:
# array(['Drama', 'Adventure', 'Action', 'Comedy', 'Horror', 'Biography',
#        'Crime', 'Fantasy', 'Family', 'Sci-Fi', 'Animation', 'Romance',
#        'Music', 'Western', 'Thriller', 'History', 'Mystery', 'Sport',
#        'Musical'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7668 entries, 0 to 7667
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7668 non-null   object
#  1   Rating    7591 non-null   object
#  2   Genre     7668 non-null   object
#  3   Year      7668 non-null   int64
#  4   Released  7666 non-null   object
#  5   Score     7665 non-null   float64
#  6   Votes     7665 non-null   float64
#  7   Director  7668 non-null   object
#  8   Writer    7665 non-null   object
#  9   Star      7667 non-null   object
#  10  Country   7665 non-null   object
#  11  Budget    5497 non-null   float64
#  12  Gross     7479 non-null   float64
#  13  Company   7651 non-null   object
#  14  Runtime   7664 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 898.7+ KB

# %%
#for renaming columns
df.rename(columns = {'name': 'Name','rating':'Rating'}, inplace = True)

# %%
df_col = ['Name', 'Rating', 'Genre', 'Year', 'Released', 'Score', 'Votes',
       'Director', 'Writer', 'Star', 'Country', 'Budget', 'Gross', 'Company',
       'Runtime']

# %%
#for renaming columns in bulk
df_col = ['Name', 'Rating', 'Genre', 'Year', 'Released', 'Score', 'Votes',
       'Director', 'Writer', 'Star', 'Country', 'Budget', 'Gross', 'Company',
       'Runtime']
df.columns = df_col
df.columns
# Out:
# Index(['Name', 'Rating', 'Genre', 'Year', 'Released', 'Score', 'Votes',
#        'Director', 'Writer', 'Star', 'Country', 'Budget', 'Gross', 'Company',
#        'Runtime'],
#       dtype='object')

# %%
#filtering for a specific field in a column
df[df['Genre'].isin(['Drama','Horror'])]
# Out:
#                    Name Rating   Genre  Year  \
# 0           The Shining      R   Drama  1980
# 5       Friday the 13th      R  Horror  1980
# 13      Ordinary People      R   Drama  1980
# 15    Somewhere in Time     PG   Drama  1980
# 16                 Fame      R   Drama  1980
# ...                 ...    ...     ...   ...
# 7661   Love by Drowning      R   Drama  2020
# 7663       More to Life    NaN   Drama  2020
# 7665      Saving Mbango    NaN   Drama  2020
# 7666       It's Just Us    NaN   Drama  2020
# 7667          Tee em el    NaN  Horror  2020
#
#                                 Released  Score     Votes            Director  \
# 0          June 13, 1980 (United States)    8.4  927000.0     Stanley Kubrick
# 5            May 9, 1980 (United States)    6.4  123000.0  Sean S. Cunningham
# 13    September 19, 1980 (United States)    7.7   49000.0      Robert Redford
# 15       October 3, 1980 (United States)    7.2   27000.0      Jeannot Szwarc
# ...

# %%
genfil = df[df['Genre'].isin(['Drama','Horror']) == False]

genfil['Genre'].unique()
# Out:
# array(['Adventure', 'Action', 'Comedy', 'Biography', 'Crime', 'Fantasy',
#        'Family', 'Sci-Fi', 'Animation', 'Romance', 'Music', 'Western',
#        'Thriller', 'History', 'Mystery', 'Sport', 'Musical'], dtype=object)

# %%
#changing data type
df['Budget'] = df['Budget'].fillna(0)
df['Budget'] = df['Budget'].astype('int64')

# %%
df['Released'] = df['Released'].astype('string')
df
# Out:
#                                                 Name     Rating      Genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       Year                           Released  Score      Votes  \
# ...

# %%
df.iloc[0:3,1:3]
# Out:
#   Rating      Genre
# 0      R      Drama
# 1      R  Adventure
# 2     PG     Action

# %%
#when x=0 it will return text left of delimeter, if x=1 then it will return text on right of delimeter
def strsplt(Released,x):
    if not pd.isna(Released):
        return Released.split('(')[x].replace(')','')

# %%
df['Rdate'] = df['Released'].apply(lambda Released : strsplt(Released,0))
df['Rcon'] = df['Released'].apply(lambda Released : strsplt(Released,1))
#df['Rdate'] = df['Rdate'].astype('string')
#df['Rdate'] = df['Released'].apply(strsplt(Released))
df['Rdate']
df
# Out:
#                                                 Name     Rating      Genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       Year                           Released  Score      Votes  \
# ...

# %%
df['Rdate'] = df['Rdate'].str.replace(',','')
df['Rdate']
# Out:
# 0           June 13 1980
# 1            July 2 1980
# 2           June 20 1980
# 3            July 2 1980
# 4           July 25 1980
#               ...
# 7648     January 17 2020
# 7649    February 14 2020
# 7650     January 17 2020
# 7651    February 21 2020
# 7652      August 28 2020
# Name: Rdate, Length: 5436, dtype: object

# %%
df['Rdate'] = pd.to_datetime(df['Rdate'])
df['Rdate']
df
# Out:
#                                                 Name     Rating      Genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       Year                           Released  Score      Votes  \
# ...

# %%
def strext(Released):
    if not pd.isna(Released):
        return Released[Released.find('(')+1 : Released.find(')')]

# %%
df['Released'].apply(lambda Released :strext(Released))
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 7648    United States
# 7649    United States
# 7650    United States
# 7651    United States
# 7652    United States
# Name: Released, Length: 5436, dtype: object

# %%
def strext(Released):
    if not pd.isna(Released):
        return Released[Released.find(',')+1 : Released.find('(')]

# %%
df['YearOcr'] = df['Released'].apply(lambda Released :strext(Released))

# %%
df

# %%
pd.set_option('display.max_rows', None)

# %%
sns.regplot(x='Budget',y='Gross', data=df)
# Out:
# <AxesSubplot:xlabel='Budget', ylabel='Gross'>

# %%
df.corr()
# Out:
#              Year     Score     Votes    Budget     Gross   Runtime
# Year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# Score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# Votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# Budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# Gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# Runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000
